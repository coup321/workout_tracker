# %%
import pandas as pd

# %%
df = pd.read_excel('../data/old_training.xlsx')

# %%
df
# Out:
#               BP  I DBP  Machine Press  Pullover  Tri Pushdown Lat pulldown  \
# 2/21/2018  165.0   45.0          100.0      37.5          57.5          NaN
# 2/22/2018    NaN    NaN            NaN       NaN           NaN          NaN
# 2/23/2018    NaN    NaN            NaN       NaN           NaN          NaN
# 2/24/2018  175.0   50.0          100.0      42.5          57.5          NaN
# 2/25/2018    NaN    NaN            NaN       NaN           NaN          140
# 2/26/2018    NaN    NaN            NaN       NaN           NaN          NaN
# 2/27/2018    NaN    NaN            NaN       NaN           NaN          NaN
# 2/28/2018  185.0   50.0          120.0      47.5          65.0          NaN
# 3/1/2018     NaN    NaN            NaN       NaN           NaN          140
# 3/2/2018     NaN    NaN            NaN       NaN           NaN          NaN
# 3/3/2018     NaN    NaN            NaN       NaN           NaN          NaN
# ...
